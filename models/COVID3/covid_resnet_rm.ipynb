# %% [markdown]
# # COVID 19 classification

# %% [raw]
# robert.marti@udg.edu

# %%
 import os
 os.environ['CUDA_DEVICE_ORDER']='PCI_BUS_ID'
 os.environ['CUDA_VISIBLE_DEVICES']='1'

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# We import all the necessary packages. We are going to work with the [fastai V1 library](http://www.fast.ai/2018/10/02/fastai-ai/) which sits on top of [Pytorch 1.0](https://hackernoon.com/pytorch-1-0-468332ba5163). The fastai library provides many useful functions that enable us to quickly and easily build neural networks and train our models.

# %%
from fastai.vision import *
from fastai.metrics import error_rate
import fastai; fastai.__version__
# Out:
# '1.0.60'

# %%
#!pip list

# %% [markdown]
# If you're using a computer with an unusually small GPU, you may get an out of memory error when running this notebook. If this happens, click Kernel->Restart, uncomment the 2nd line below to use a smaller *batch size* (you'll learn all about what this means during the course), and try again.

# %%
bs = 16
# bs = 16   # uncomment this line if you run out of memory even after clicking Kernel->Restart
size_level_1 = 256
size_level_2 = 512

# %% [markdown]
# ## data

# %%
path ='/home/robert/data/covid/'; path
# Out:
# '/home/robert/data/covid/'

# %% [markdown]
# ### Load Normal and pneumonia from dataset (not covids!)

# %%
dfTrain = pd.read_csv(path+'train/train_split_v2_n.csv', header=None)
dfTrain['valid'] = 0
dfTrain[0] = 'train/' + dfTrain[0].astype(str)
dfTrain.head()
# Out:
#                                                    0          1  valid
# 0  train/SARS-10.1148rg.242035193-g04mr34g0-Fig8a...  pneumonia      0
# 1  train/SARS-10.1148rg.242035193-g04mr34g0-Fig8b...  pneumonia      0
# 2  train/SARS-10.1148rg.242035193-g04mr34g0-Fig8c...  pneumonia      0
# 3  train/SARS-10.1148rg.242035193-g04mr34g04a-Fig...  pneumonia      0
# 4  train/SARS-10.1148rg.242035193-g04mr34g04b-Fig...  pneumonia      0

# %% [markdown]
# ### Load COVID for training from covid_vicorob

# %%
dfTrainCovid = pd.read_csv(path+'covid_vicorob/covid_vicorob.csv', header=None)
dfTrainCovid['valid'] = 0
dfTrainCovid[0] = 'covid_vicorob/' + dfTrainCovid[0].astype(str)
dfTrainCovid.head()
print(len (dfTrainCovid))
#augment de training covid data 2^3
for i in range(3):
    dfTrainCovid = dfTrainCovid.append(dfTrainCovid)
print(len (dfTrainCovid))

dfTrain = dfTrain.append(dfTrainCovid)
# Out:
# 122
# 976

# %% [markdown]
# ### Validation data from Seram & Normals

# %%
dfTest = pd.read_csv(path+'test/test_split_v2_n.csv',header=None)
dfTest['valid'] = 1
dfTest[0] = 'test/' + dfTest[0].astype(str)
dfTest.head()
# Out:
#                                                    0          1  valid
# 0  test/SARS-10.1148rg.242035193-g04mr34g05x-Fig5...  pneumonia      1
# 1  test/streptococcus-pneumoniae-pneumonia-tempor...  pneumonia      1
# 2  test/streptococcus-pneumoniae-pneumonia-tempor...  pneumonia      1
# 3  test/streptococcus-pneumoniae-pneumonia-tempor...  pneumonia      1
# 4  test/streptococcus-pneumoniae-pneumonia-tempor...  pneumonia      1

# %%
dfTestCovid = pd.read_csv(path+'seram/covid_seram.csv',header=None)
dfTestCovid['valid'] = 1
dfTestCovid[0] = 'seram/' + dfTestCovid[0].astype(str)
dfTestCovid.head()
dfTest= dfTest.append(dfTestCovid)

# %%
df = dfTrain.append(dfTest)
df.head()
# Out:
#                                                    0          1  valid
# 0  train/SARS-10.1148rg.242035193-g04mr34g0-Fig8a...  pneumonia      0
# 1  train/SARS-10.1148rg.242035193-g04mr34g0-Fig8b...  pneumonia      0
# 2  train/SARS-10.1148rg.242035193-g04mr34g0-Fig8c...  pneumonia      0
# 3  train/SARS-10.1148rg.242035193-g04mr34g04a-Fig...  pneumonia      0
# 4  train/SARS-10.1148rg.242035193-g04mr34g04b-Fig...  pneumonia      0

# %%
np.random.seed(42)

# src = (ImageList.from_csv(path, 'train_v2.csv', folder='train-jpg', suffix='.jpg')
#        .split_by_rand_pct(0.2)
#        .label_from_df(label_delim=' '))

src = (ImageList.from_df(df=df,path=path)
    .split_from_df(col='valid')
    .label_from_df())

# %%
# original tfms = get_tranasforms(do_flip=False) 
# allowing horizontal flips only. 
tfms = get_transforms(flip_vert=False, max_lighting=0.1, max_zoom=1.05, max_warp=0.)
#tfms = get_transforms(flip_vert=False)

# %%
#data = #ImageDataBunch.from_df(path=Path('data'), df=df, ds_tfms=get_transforms(), size=224, bs=32)

data = (src.transform(tfms, size=256)
        .databunch().normalize(imagenet_stats))
data.batch_size=bs
# lesson 1 data = ImageDataBunch.from_folder(path, ds_tfms=tfms, size=224, resize_method=ResizeMethod.SQUISH)

# %%
#data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2, ds_tfms=tfms, size=224, resize_method=ResizeMethod.SQUISH)

# %%
data.show_batch(rows=10,figsize=(15,15))

# %%
data.train_ds
# Out:
# LabelList (18041 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: CategoryList
# pneumonia,pneumonia,pneumonia,pneumonia,pneumonia
# Path: /home/robert/data/covid

# %%
data.valid_ds
# Out:
# LabelList (2017 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: CategoryList
# pneumonia,pneumonia,pneumonia,pneumonia,pneumonia
# Path: /home/robert/data/covid

# %% [markdown]
# ### Convert to grayscale

# %%
for itemList in ["train_dl", "valid_dl", "fix_dl", "test_dl"]:
    itemList = getattr(data, itemList)
    if itemList: itemList.x.convert_mode = "L"

# %% [markdown]
# ## learner

# %%
'''class fbeta_binary(Callback):
    "Computes the f_beta between preds and targets for binary text classification"

    def __init__(self, beta2 = 1, eps=1e-9,sigmoid = True):      
        self.beta2=beta2**2
        self.eps = eps
        self.sigmoid = sigmoid
    
    def on_epoch_begin(self, **kwargs):
        self.TP = 0
        self.total_y_pred = 0   
        self.total_y_true = 0
    
    def on_batch_end(self, last_output, last_target, **kwargs):
        y_pred = last_output
        y_pred = y_pred.softmax(dim = 1)        
        y_pred = y_pred.argmax(dim=1)
        y_true = last_target.float()
        
        self.TP += ((y_pred==1) * (y_true==1)).float().sum()
        self.total_y_pred += (y_pred==1).float().sum()
        self.total_y_true += (y_true==1).float().sum()
    
    def on_epoch_end(self, **kwargs):
        prec = self.TP/(self.total_y_pred+self.eps)
        rec = self.TP/(self.total_y_true+self.eps)
        res = (prec*rec)/(prec*self.beta2+rec+self.eps)*(1+self.beta2)        
        #self.metric = res.mean()
        self.metric = res     
'''
# Out:
# 'class fbeta_binary(Callback):\n    "Computes the f_beta between preds and targets for binary text classification"\n\n    def __init__(self, beta2 = 1, eps=1e-9,sigmoid = True):      \n        self.beta2=beta2**2\n        self.eps = eps\n        self.sigmoid = sigmoid\n    \n    def on_epoch_begin(self, **kwargs):\n        self.TP = 0\n        self.total_y_pred = 0   \n        self.total_y_true = 0\n    \n    def on_batch_end(self, last_output, last_target, **kwargs):\n        y_pred = last_output\n        y_pred = y_pred.softmax(dim = 1)        \n        y_pred = y_pred.argmax(dim=1)\n        y_true = last_target.float()\n        \n        self.TP += ((y_pred==1) * (y_true==1)).float().sum()\n        self.total_y_pred += (y_pred==1).float().sum()\n        self.total_y_true += (y_true==1).float().sum()\n    \n    def on_epoch_end(self, **kwargs):\n        prec = self.TP/(self.total_y_pred+self.eps)\n        rec = self.TP/(self.total_y_true+self.eps)\n        res = (prec*rec)/(prec*self.beta2+rec+self.eps)*(1+self.beta2)        \n        #self.metric = res.mean()\n        self.metric = res     \n'

# %%
#learn = cnn_learner(data, models.resnet34, metrics=error_rate)

arch = models.resnet50
#arch = models.densenet161
#learn = cnn_learner(data, arch, metrics=[accuracy, Precision(), AUROC(), error_rate])
learn = cnn_learner(data, arch, metrics=[accuracy, Precision(), error_rate])

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='90' class='' max='1127', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       7.99% [90/1127 00:09<01:53 6.4256]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot(suggestion=True)
# Out:
# Min numerical gradient: 5.75E-04
# Min loss divided by 10: 8.32E-03

# %%
lr = 1e-03

# %%
learn.fit_one_cycle(10, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.602229</td>
#       <td>0.380793</td>
#       <td>0.877541</td>
#       <td>0.829230</td>
#       <td>0.122459</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.330894</td>
#       <td>0.223940</td>
#       <td>0.919683</td>
#       <td>0.921384</td>
#       <td>0.080317</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.252779</td>
#       <td>0.196811</td>
#       <td>0.927615</td>
#       <td>0.911925</td>
#       <td>0.072385</td>
#       <td>01:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.235837</td>
#       <td>0.193434</td>
#       <td>0.926128</td>
#       <td>0.951126</td>
#       <td>0.073872</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.208347</td>
#       <td>0.162807</td>
#       <td>0.937531</td>
#       <td>0.946389</td>
#       <td>0.062469</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.201976</td>
#       <td>0.161394</td>
#       <td>0.939018</td>
#       <td>0.947420</td>
#       <td>0.060982</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.184503</td>
#       <td>0.141932</td>
#       <td>0.948934</td>
#       <td>0.955345</td>
#       <td>0.051066</td>
#       <td>01:24</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.145662</td>
#       <td>0.145820</td>
#       <td>0.946951</td>
#       <td>0.954014</td>
#       <td>0.053049</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.179927</td>
#       <td>0.143403</td>
#       <td>0.949926</td>
#       <td>0.956575</td>
#       <td>0.050074</td>
#       <td>01:31</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.172558</td>
#       <td>0.144785</td>
#       <td>0.944472</td>
#       <td>0.952739</td>
#       <td>0.055528</td>
#       <td>01:24</td>
#     </tr>
#   </tbody>
# </table>
# /home/robert/miniconda2/envs/fastai-3.6/lib/python3.6/site-packages/fastai/metrics.py:191: UserWarning: average=`binary` was selected for a non binary case. Value for average has now been set to `macro` instead.
#   warn("average=`binary` was selected for a non binary case. Value for average has now been set to `macro` instead.")

# %%
learn.save('stage-1-256-dn50')

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['COVID-19', 'normal', 'pneumonia'], 3, 18041, 2017)

# %%
interp.plot_top_losses(10, figsize=(15,11), heatmap= True)

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=1)
# Out:
# [('normal', 'pneumonia', 54),
#  ('pneumonia', 'normal', 49),
#  ('COVID-19', 'pneumonia', 7),
#  ('pneumonia', 'COVID-19', 2)]

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6' class='' max='1127', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.53% [6/1127 00:02<06:55 0.1186]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot(suggestion=True)
# Out:
# Failed to compute the gradients, there might not be enough points.

# %%
learn.fit_one_cycle(10,slice(1e-5, lr/2))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.192199</td>
#       <td>0.155287</td>
#       <td>0.938523</td>
#       <td>0.930370</td>
#       <td>0.061477</td>
#       <td>01:55</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.202528</td>
#       <td>0.157769</td>
#       <td>0.942985</td>
#       <td>0.910938</td>
#       <td>0.057015</td>
#       <td>02:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.192358</td>
#       <td>0.121091</td>
#       <td>0.954884</td>
#       <td>0.959745</td>
#       <td>0.045117</td>
#       <td>01:58</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.161236</td>
#       <td>0.138541</td>
#       <td>0.948438</td>
#       <td>0.963893</td>
#       <td>0.051562</td>
#       <td>01:58</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.146100</td>
#       <td>0.124474</td>
#       <td>0.955379</td>
#       <td>0.949358</td>
#       <td>0.044621</td>
#       <td>01:57</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.116072</td>
#       <td>0.105324</td>
#       <td>0.962816</td>
#       <td>0.973854</td>
#       <td>0.037184</td>
#       <td>01:57</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.100573</td>
#       <td>0.119455</td>
#       <td>0.957362</td>
#       <td>0.969821</td>
#       <td>0.042638</td>
#       <td>01:57</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.063071</td>
#       <td>0.107126</td>
#       <td>0.961329</td>
#       <td>0.972838</td>
#       <td>0.038671</td>
#       <td>01:57</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.054831</td>
#       <td>0.105740</td>
#       <td>0.964303</td>
#       <td>0.974910</td>
#       <td>0.035697</td>
#       <td>01:58</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.048430</td>
#       <td>0.109347</td>
#       <td>0.967278</td>
#       <td>0.976982</td>
#       <td>0.032722</td>
#       <td>02:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2-256-rn50')

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %% [markdown]
# ### increasing image size

# %%
data = (src.transform(tfms, size=512)
        .databunch().normalize(imagenet_stats))

learn.data = data
data.batch_size = bs
data.train_ds[0][0].shape
# Out:
# torch.Size([1, 512, 512])

# %%
learn.freeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='83' class='' max='1127', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       7.36% [83/1127 00:22<04:37 1.5933]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr=1e-3/2

# %%
learn.fit_one_cycle(10, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.249905</td>
#       <td>0.169877</td>
#       <td>0.931582</td>
#       <td>0.930226</td>
#       <td>0.068418</td>
#       <td>04:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.157937</td>
#       <td>0.130668</td>
#       <td>0.954884</td>
#       <td>0.963907</td>
#       <td>0.045117</td>
#       <td>04:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.156713</td>
#       <td>0.117015</td>
#       <td>0.955379</td>
#       <td>0.968465</td>
#       <td>0.044621</td>
#       <td>04:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.145990</td>
#       <td>0.111705</td>
#       <td>0.962816</td>
#       <td>0.973573</td>
#       <td>0.037184</td>
#       <td>04:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.120201</td>
#       <td>0.107243</td>
#       <td>0.961329</td>
#       <td>0.972559</td>
#       <td>0.038671</td>
#       <td>04:17</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.106633</td>
#       <td>0.107833</td>
#       <td>0.959346</td>
#       <td>0.971367</td>
#       <td>0.040654</td>
#       <td>04:17</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.099061</td>
#       <td>0.104390</td>
#       <td>0.959346</td>
#       <td>0.971335</td>
#       <td>0.040654</td>
#       <td>04:17</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.102640</td>
#       <td>0.104148</td>
#       <td>0.956371</td>
#       <td>0.969346</td>
#       <td>0.043629</td>
#       <td>04:17</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.087390</td>
#       <td>0.104285</td>
#       <td>0.958850</td>
#       <td>0.971151</td>
#       <td>0.041150</td>
#       <td>04:17</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.087162</td>
#       <td>0.104601</td>
#       <td>0.957858</td>
#       <td>0.970296</td>
#       <td>0.042142</td>
#       <td>04:17</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1-512-rn50')

# %%
learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='49' class='' max='1127', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       4.35% [49/1127 00:17<06:26 0.1306]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(10, slice(1e-5, lr/5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.086217</td>
#       <td>0.111783</td>
#       <td>0.960337</td>
#       <td>0.972979</td>
#       <td>0.039663</td>
#       <td>05:58</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.075963</td>
#       <td>0.104062</td>
#       <td>0.962816</td>
#       <td>0.974387</td>
#       <td>0.037184</td>
#       <td>05:59</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.113208</td>
#       <td>0.100528</td>
#       <td>0.965295</td>
#       <td>0.971322</td>
#       <td>0.034705</td>
#       <td>05:58</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.083415</td>
#       <td>0.115162</td>
#       <td>0.960833</td>
#       <td>0.973365</td>
#       <td>0.039167</td>
#       <td>05:57</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.075608</td>
#       <td>0.107554</td>
#       <td>0.959841</td>
#       <td>0.971866</td>
#       <td>0.040159</td>
#       <td>05:59</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.079532</td>
#       <td>0.106382</td>
#       <td>0.960337</td>
#       <td>0.971926</td>
#       <td>0.039663</td>
#       <td>06:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.037263</td>
#       <td>0.120328</td>
#       <td>0.962816</td>
#       <td>0.974142</td>
#       <td>0.037184</td>
#       <td>06:02</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.027652</td>
#       <td>0.119046</td>
#       <td>0.959346</td>
#       <td>0.971543</td>
#       <td>0.040654</td>
#       <td>06:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.032322</td>
#       <td>0.125481</td>
#       <td>0.962320</td>
#       <td>0.973305</td>
#       <td>0.037680</td>
#       <td>05:59</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.017066</td>
#       <td>0.125337</td>
#       <td>0.960337</td>
#       <td>0.972037</td>
#       <td>0.039663</td>
#       <td>06:02</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.save('stage-2-512-rn50')

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.plot_top_losses(10, figsize=(15,11), largest=True, heatmap= True)

# %%
interp.plot_top_losses(10, figsize=(15,11), largest=False, heatmap= True)

# %%
learn.export('trainedAllData_resnet_512_export.pkl')

# %% [markdown]
# ### Test on new data

# %%
learn = load_learner(path,'trainedAllData_resnet_512_export.pkl')


#preds,y = learn.get_preds()

# %%
#dfTest = pd.read_csv(path+'covid_local/covid_local_APonly.csv',header=None)
#dfTest[0] = 'covid_local/' + dfTest[0].astype(str)
#dfTest.head()

#CSMS
dfTest = pd.read_csv(path+'CSMS/CSMS.csv',header=None)
dfTest[0] = 'CSMS/' + dfTest[0].astype(str)
dfTest.head()


#dfTest2 = pd.read_csv(path+'padchest/test_split_np.csv',header=None)
#dfTest2[0] = 'padchest/' + dfTest[0].astype(str)
#dfTest2.head()

#dfTest = dfTest.append(dfTest2)
#dfTest.head()




#preds,y = learn.get_preds(ds_type=DatasetType.Train)

#data_test = (TabularList.from_df(test, path=nbPath, cat_names=cat_var, cont_names=cont_var,
                          # procs=procs, processor=data.processor)
#       .split_none()
#       .label_from_df(dep_var, classes=classes)
#       .databunch())
#learn.data.valid_dl = data_test.train_dl

#cls = ClassificationInterpretation.from_learner(learn, ds_type=DatasetType.Valid)
# Out:
#                    0         1
# 0  CSMS/001_CSMS.jpg  COVID-19
# 1  CSMS/002_CSMS.jpg  COVID-19
# 2  CSMS/003_CSMS.jpg  COVID-19
# 3  CSMS/004_CSMS.jpg    normal
# 4  CSMS/005_CSMS.jpg    normal

# %%
src = (ImageList.from_df(df=dfTest,path=path,convert_mode='L')
    .split_none()
    .label_from_df())

test = (src.transform(tfms, size=512)
        .databunch(no_check=False,bs=1).normalize(imagenet_stats))
test.train_dl
# Out:
# DeviceDataLoader(dl=<torch.utils.data.dataloader.DataLoader object at 0x7f54587e8b38>, device=device(type='cuda', index=0), tfms=[functools.partial(<function _normalize_batch at 0x7f54591b6598>, mean=tensor([0.4850, 0.4560, 0.4060]), std=tensor([0.2290, 0.2240, 0.2250]), do_x=True, do_y=False)], collate_fn=<function data_collate at 0x7f54615ea268>)

# %%
test.valid_dl = test.train_dl

test.show_batch(rows=10,figsize=(15,15))

for itemList in ["train_dl", "valid_dl", "fix_dl", "test_dl"]:
    itemList = getattr(test, itemList)
    if itemList: itemList.x.convert_mode = "L"


learn.data.valid_dl = test.train_dl
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()

#len(data.valid_ds)==len(losses)==len(idxs)
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
log_preds, y = learn.get_preds()

predIdxs = np.argmax(log_preds.numpy(), axis=1)
print(exp(log_preds))
# Out:
# tensor([[1.0020, 2.6998, 1.0048],
#         [2.7176, 1.0000, 1.0003],
#         [1.0724, 2.2733, 1.1150],
#         [2.3426, 1.0007, 1.1596],
#         [1.0000, 1.0005, 2.7170],
#         [2.7110, 1.0001, 1.0026],
#         [2.7163, 1.0000, 1.0007],
#         [2.7183, 1.0000, 1.0000],
#         [1.0011, 2.7126, 1.0010],
#         [2.6699, 1.0066, 1.0114],
#         [2.6169, 1.0036, 1.0350],
#         [2.5808, 1.0048, 1.0483],
#         [2.7173, 1.0001, 1.0003],
#         [2.6821, 1.0096, 1.0038],
#         [2.7057, 1.0005, 1.0041],
#         [1.0000, 1.0002, 2.7177],
#         [2.4456, 1.0000, 1.1115],
#         [2.7182, 1.0000, 1.0000],
#         [2.6991, 1.0027, 1.0044],
#         [1.0180, 2.6685, 1.0006],
#         [2.7166, 1.0003, 1.0003],
#         [2.7152, 1.0002, 1.0009],
#         [2.5212, 1.0782, 1.0000],
#         [2.7142, 1.0000, 1.0015],
#         [2.7123, 1.0000, 1.0022],
#         [2.6852, 1.0000, 1.0123],
#         [2.0844, 1.3037, 1.0003],
#         [2.5152, 1.0000, 1.0807],
#         [2.3840, 1.0011, 1.1389],
#         [2.7183, 1.0000, 1.0000],
#         [2.7134, 1.0001, 1.0017],
#         [2.7138, 1.0001, 1.0015],
#         [2.7176, 1.0002, 1.0000],
#         [2.7160, 1.0004, 1.0005],
#         [1.0000, 2.7171, 1.0004],
#         [1.0168, 2.5231, 1.0595],
#         [2.7182, 1.0000, 1.0000],
#         [1.0044, 2.6914, 1.0056],
#         [2.4917, 1.0267, 1.0625],
#         [2.3050, 1.1790, 1.0003],
#         [2.7132, 1.0000, 1.0019],
#         [1.6234, 1.4429, 1.1605],
#         [2.7160, 1.0000, 1.0008]])

# %%
len(data.valid_ds)
predIdxs
log_preds
predIdxs
# Out:
# array([2, 2, 2, 2, ..., 2, 2, 2, 2])

# %%
interp.plot_top_losses(25, figsize=(15,11), largest=True, heatmap= True)
